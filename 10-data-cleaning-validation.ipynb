# %%
import pandas as pd
# Out:
# /Users/stoneman/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/stoneman/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('/Users/stoneman/Library/CloudStorage/OneDrive-Vanderbilt/Social_Network_Analysis/Amazon_Recommandation_Project/data/products_train.csv')

# %%
df.head(20)
# Out:
#             id locale                                              title  \
# 0   B005ZSSN10     DE  RED DRAGON Amberjack 3 - Steel Tip 22 Gramm Wo...
# 1   B08PRYN6LD     DE  Simply Keto Lower Carb* Schokodrops ohne Zucke...
# 2   B09MBZJ48V     DE  Sennheiser 508377 PC 5.2 Chat, Stilvolles Mult...
# 3   B08ZN6F26S     DE  AmyBenton Auto ab 1 2 3 ahre - Baby Aufziehbar...
# 4   B094DGRV7D     DE      PLAYMOBIL - 70522 - Cavaliere mit grauem Pony
# 5   B09JNNBDH5     DE  URBZUE Handwärmer, 10000mAh USB aufladbar und ...
# 6   B08R62WZ1Y     DE  Kinderkopfhörer Bluetooth, Mädchen Katzenohr K...
# 7   B09WK4YNX8     DE  8 Stück Herd Schalter Schutz, Küche Gasherd Kn...
# 8   B07KTKFYYS     DE  AVANA Edelstahl Ausstechformen 12 Stück Ringe ...
# 9   B0B9MPKYJK     DE  Amstory Stirnlampe LED Wiederaufladbar Joggen ...
# 10  B0B5RMZ9FQ     DE  Halloween deko gruselig gartendekoration Hexe,...
# 11  B000LXWTUU     DE  Canina 74161 8 Petvital Verminex, 50 ml (1er P...
# ...

# %%
df.shape
# Out:
# (1551057, 11)

# %% [markdown]
# **In the training dataset, there are about 1.5 million rows and 11 columns.**

# %%
df.isna().sum(axis=0)
# Out:
# id                0
# locale            0
# title             8
# price             0
# brand         19371
# color        425629
# size         633966
# model        789922
# material     716675
# author      1477548
# desc         126974
# dtype: int64

# %%
print('Percentage of missing values in each columns:')
df.isna().sum(axis=0)/df.shape[0]*100
# Out:
# Percentage of missing values in each columns:
# id           0.000000
# locale       0.000000
# title        0.000516
# price        0.000000
# brand        1.248890
# color       27.441222
# size        40.873159
# model       50.927980
# material    46.205588
# author      95.260716
# desc         8.186288
# dtype: float64

# %%
# Loop through all columns to get unique values
for column in df.columns:
    num_unique_values = df[column].nunique()
    print(f"{column}: (Unique Count: {num_unique_values})")
    print()
# Out:
# id: (Unique Count: 1410675)
#
# locale: (Unique Count: 6)
#
# title: (Unique Count: 1494642)
#
# price: (Unique Count: 39244)
#
# brand: (Unique Count: 178775)
#
# color: (Unique Count: 219993)
#
# size: (Unique Count: 231617)
#
# model: (Unique Count: 524216)
#
# material: (Unique Count: 49613)
#
# author: (Unique Count: 30916)
#
# desc: (Unique Count: 884538)

# %%
# Find the rows without any missing values
df_nonan = df.dropna()
df_nonan.shape
# Out:
# (421, 11)
